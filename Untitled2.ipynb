# %% [markdown]
# <a href="https://colab.research.google.com/github/Vickymaurya1/machine-learning-course/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **What is Linear Regression?**
#
# Linear Regression is a supervised learning algorithm used to predict a continuous value.
#
# It finds a linear relationship between:
#
# Independent variable(s) (X)
#
# Dependent variable (y)
#
# 🔹 Basic Idea
#
# It fits a straight line to the data.
#
# Equation of Simple Linear Regression:
#
# y=mx+c

# %%
import pandas as pd

# %%
dataset = pd.read_csv("placement.csv")

# %%
dataset.head(3)
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0    0
# cgpa          0
# iq            0
# placement     0
# dtype: int64

# %%
x1 = dataset["cgpa"]
x1.ndim
# Out:
# 1

# %% [markdown]
# #it is neccesar that our dataset should present in 2d so we convert this dataset in 2D

# %%
x = dataset[["cgpa"]]
x.ndim
# Out:
# 2
